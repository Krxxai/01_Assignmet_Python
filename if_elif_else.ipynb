# %%
# 11.	Ask user to enter the marks and define if the user got distinction, first class, second class, pass, Fails
# If marks are more than 80 output must be “You got distinction”
# For marks more than 60 output must be “You got First class”
# Marks more than 40 will display “You got second class”
# Marks more than or equal to 35 “PASS” Otherwise Fail

marks=int(input("Enter your marks :"))

if marks>80:
    print("You got distinction!!!")
elif marks>60:
    print("You got first class!!!")
elif marks>40:
    print("You got second class!!!")
elif marks>=35:
    print("PASS!!!")
else:
    print("FAIL!!!")
# Out:
# You got distinction!!!

# %%
# 12.	Ask user to enter information about salary of the employee per year and rating received as A, B, C, D
# If salary upto 5 lpa then increament based on ratings are  A = 16% , B=12%, C= 10%, D=6%
# If salary upto 10 lpa then increament based on ratings are  A = 14% , B=10%, C= 8%, D=6%
# If salary upto 15 lpa then increament based on ratings are  A = 8% , B=6%, C= 4%, D = no increment
# If salary upto 23 lpa then increament based on ratings are  A = 7% , B=5%, C= 4%, D=no


sal=int(input("Enter yor salary (per annum) :"))
rating=input("Rating received (A,B,C,D):")

if sal<=500000:
    if rating=='A':
        inc_amt=sal*16/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)
    elif rating=='B':
        inc_amt=sal*12/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)
    elif rating=='C':
        inc_amt=sal*10/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)
    elif rating=='D':
        inc_amt=sal*6/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)

elif sal<=1000000:
    if rating=='A':
        inc_amt=sal*14/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)
    elif rating=='B':
        inc_amt=sal*10/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)
    elif rating=='C':
        inc_amt=sal*8/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)
    elif rating=='D':
        inc_amt=sal*6/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)

elif sal<=1500000:
    if rating=='A':
        inc_amt=sal*8/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)
    elif rating=='B':
        inc_amt=sal*6/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)
    elif rating=='C':
        inc_amt=sal*4/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)
    elif rating=='D':
        print("No increment")

elif sal<=2300000:
    if rating=='A':
        inc_amt=sal*7/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)
    elif rating=='B':
        inc_amt=sal*5/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)
    elif rating=='C':
        inc_amt=sal*4/100
        sal=sal+inc_amt
        print("Salary after increment is ",sal)
    elif rating=='D':
        print("No increment")
# Out:
# Salary after increment is  116000.0

# %%
# 13.	user to opt for courses for master degree based on the following
# L1 = [“HR”, “Finance”, “Marketing”, “DS”]
# Based on above subject there are two different streams. For example- HR is having HR core and HR analytics and 
# Marketing is having core and Marketing analytics. 
# Analytics is the optional subject and having added extra fees.
#  DS is not having analytics.
# If fees for L1 is 2 lakhs for each course core subject having the same fees but analytics subject having 10% extra on 2 lakhs.
# If student opts for hostel then 2 lakhs per year is added. For food monthly 2000 .
# Transportation charges 13000 per semester. Calculate the total annual cost based on selected service.  
# User will enter values as subject, analytics(Y/N), Hostel (Y/N), food(How many months?), Transportation(semester/annual)

course=input("Enter Your Course(HR,FINANCE,MARKETING,DS) :")
if course=='HR' or course=='FINANCE' or course=='MARKETING':
    sub=input("Enter Your Subject Stream (Core/Analytics):")
if course=='DS':
    sub='Core'
hos=input("Do you want hostel ?(Y/N)")
food=input("Do you want food ?(Y/N)")
tran=input("Do you want transportation? (Y/N)")
if tran=='Y':
    ans=input("For Semester or Annual (S/A):")
fees=200000
if sub=='Core':
    fees=200000
elif sub=='Analytics':
    incr_amt=fees*10/100
    fees=fees+incr_amt

if hos=='Y':
    hos_fees=200000
else:
    hos_fees=0
if food=='Y':
    food_charges=2000
    tot_food_charges=food_charges * 12
else:
    food_charges=0
    tot_food_charges=0

if tran=='Y' and ans=='S':
    tran_charges=13000
elif tran=='Y' and ans=='A':
    tran_charges=25000
else:
    tran_charges=0

print("Your Total Cost including course fees,hostel,food,tranportation fees is ",fees + hos_fees + tot_food_charges + tran_charges)
# Out:
# Your Total Cost including course fees,hostel,food,tranpotation fees is  437000

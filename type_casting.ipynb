# %%
# # 17.	Create a=100 
a=100

# %%
# •	Convert a to string 
a=str(a)
a
# Out:
# '100'

# %%
# •	Convert a to list    
a=list(a)
a
# Out:
# ['1', '0', '0']

# %%
# •	Convert a to tuple  
a=tuple(a)
a
# Out:
# ('1', '0', '0')

# %%
# •	Convert a to dict 
a=(('1','0'),('0','0'))
b=dict(a)
b
# Out:
# {'1': '0', '0': '0'}

# %%
# •	Convert a to set 
b=set(b)
b
# Out:
# {'0', '1'}

# %%
# •	Convert to float 
b=float(b) #TypeError: float() argument must be a string or a real number, not 'set'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # •	Convert to float
# ----> 2 b=float(b)
#
# TypeError: float() argument must be a string or a real number, not 'set'
